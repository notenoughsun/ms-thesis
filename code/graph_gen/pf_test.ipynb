# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

import numpy as np

# %%
import json
import os.path
import inspect
import networkx as nx

# from networkx.readwrite.json_graph import jit_data, jit_graph
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np

# from networkx.drawing.nx_agraph import graphviz_layout
# from networkx.drawing.nx_pydot import write_dot, read_dot
# nx.drawing.nx_pydot.write_dot

from maze import maze

# %%
from routes import Mgraph
from NoisyTraj import NoisyTraj

import json
import os.path
import inspect

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = inspect.getframeinfo(inspect.currentframe()).filename
fpath = os.path.dirname(os.path.abspath(filename))
filename, fpath
# Out:
# ('<ipython-input-6-9d86ea367206>', '/home/tim/git/thesis/code/graph_gen')

# %%
from map_gen import Simulation
sim = None
sim = Simulation(11)
sim.generate_data(26)
# sim.save_data()
sim.plot_data()

# %%
# sim.mg.plot_field()

# %%
from filters.pf import PF
from tools.objects import FilterTrajectory
from tools.objects import Gaussian
from tools.plot import plot2dcov, plot_robot
# from tools.plot import plot_field, plot_observation, plot_robot
# from tools.plot import plot_field, plot_observation, plot_robot
# from tools.plot import ciplot
from tools.task import wrap_angle
import numpy as np
wrap_angle_vec = np.vectorize(wrap_angle)

# %%
Sigma_prior = 1e-12 * np.eye(3, 3)
Sigma_prior[:-1,:-1]
# Out:
# array([[1.e-12, 0.e+00],
#        [0.e+00, 1.e-12]])

# %%
def plot_field(sim, mu, sigma):
    # np.assert.isinstance 
    sim.mg.plot_field()
    plot2dcov(mu, sigma, 'blue', 3,
        legend='{} +'.format('pf'))

mean_prior = np.array([5., 5., 0.])
Sigma_prior = 1e-1 * np.eye(3, 3)

x = mean_prior
cov = Sigma_prior

print()
plot_field(sim, x[:2], cov[:2,:2])
# plot_robot(x)

# %%
from filters.pf import PF
# from tools.objects import FilterTrajectory
from tools.objects import Gaussian

# from tools.plot import plot2dcov, plot_robot
# from tools.plot import plot_field, plot_observation, plot_robot
# from tools.plot import plot_field, plot_observation, plot_robot
# from tools.plot import ciplot
from tools.task import wrap_angle
import numpy as np
wrap_angle_vec = np.vectorize(wrap_angle)

# %%
alphas = np.array((0.05, 0.001, 0.05, 0.01)) **2 # variance of noise R proportional to alphas, see tools/tasks@get_motion_noise_covariance()
beta = np.deg2rad(20) # see also filters/localization_filter.py
num_particles = 100
dt = 0.1
plot_pause_len = 0.01
# num_steps = 100
global_localization = True

# %%
mean_prior = np.array([180., 50., 0.])
Sigma_prior = 1e-12 * np.eye(3, 3)
initial_state = Gaussian(mean_prior, Sigma_prior)

field_map = None
# data = generate_input_data(initial_state.mu.T, num_steps, alphas, beta, dt, field_map)
localization_filter = PF(initial_state, alphas, beta, num_particles,global_localization)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d1129865c376> in <module>
#       5 field_map = None
#       6 # data = generate_input_data(initial_state.mu.T, num_steps, alphas, beta, dt, field_map)
# ----> 7 localization_filter = PF(initial_state, alphas, beta, num_particles,global_localization)
#
# ~/git/thesis/code/graph_gen/filters/pf.py in __init__(self, initial_state, alphas, beta, num_particles, global_localization)
#      21 class PF(LocalizationFilter):
#      22     def __init__(self, initial_state, alphas, beta, num_particles, global_localization):
# ---> 23         super(PF, self).__init__(initial_state, alphas, beta)
#      24
#      25         self.num_particles = num_particles
#
# TypeError: __init__() missing 1 required positional argument: 'field_map'

# %%
from map_gen import Simulation
from map_gen import Zspace
sim = None
sim = Simulation(11)
sim.generate_data(26)
# sim.save_data()
# sim.plot_data()

zs = Zspace(11)
zs.plot_surf()

# %%
from map_gen import Zspace
zs = Zspace(11)

# fig = plt.figure(figsize=(3,3), dpi = 150)
# fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(2,6), dpi = 150)
# ax = plt.gca()

zs.plot_3surf()
